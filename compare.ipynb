# %%
import hiclib.hiclib as hi
from importlib import reload

reload(hi)
# Out:
# <module 'hiclib.hiclib' from '/home/skyhl/Documents/production/library_implement/hiclib/hiclib.py'>

# %%
hic = hi.get_contactmap("simulation/data_out/contacts.txt")
hic_eric = hi.get_contactmap("eric/y.npy")

# %%
hi.plot_contact(hic)

# %%
hi.plot_contact(hic_eric)

# %%
hi.process("simulation", 20)
# Out:
# goals from experiment:
# [[0.00124439 0.        ]
#  [0.00022991 0.00055246]]
# goals from simulation:
# [[0.00126207 0.        ]
#  [0.00023008 0.00056766]]

# %%
hi.process("sample1")
# Out:
# goals from experiment:
# [[0.00404214 0.        ]
#  [0.00301958 0.00338181]]
# goals from simulation:
# [[0.00129743 0.        ]
#  [0.00096598 0.00108193]]
